# %% [markdown]
# Question.1 What is a random variable in probability theory?
# --- A random variable in probability theory is a variable that represents numerical outcomes of a random experiment. It assigns a real number to each possible outcome in the sample space.
# Types of Random Variables
# Discrete Random Variable
# Takes countable values (finite or infinite).
# Defined by a Probability Mass Function (PMF).
#
# Continuous Random Variable--
# Takes uncountable values (like all real numbers in an interval).
# Defined by a Probability Density Function (PDF).
#
# Question.2 What are the types of random variables?
# ---Types of Random Variables
# Discrete Random Variable
# Takes countable values (finite or infinite).
# Defined by a Probability Mass Function (PMF).
#
# Continuous Random Variable--
# Takes uncountable values (like all real numbers in an interval).
# Defined by a Probability Density Function (PDF).
#
# Question.3 What is the difference between discrete and continuous distributions?
# --- A discrete distribution is associated with a discrete random variable, which takes countable values, such as whole numbers. It is characterized by a Probability Mass Function (PMF), which assigns probabilities to individual outcomes. For example, rolling a fair die results in one of six possible values (1, 2, 3, 4, 5, or 6), and each value has a probability of
# 1
# 6
# 6
# 1
# ​
#  . In a discrete distribution, the probability of a single outcome is greater than zero, and probabilities are typically represented using bar graphs.
#
# On the other hand, a continuous distribution deals with a continuous random variable, which can take infinitely many values within a given range. Instead of a PMF, it is described by a Probability Density Function (PDF), and probabilities are found by calculating the area under the curve over an interval. A key difference is that the probability of any single value in a continuous distribution is zero; only ranges of values have nonzero probabilities. For instance, a person's height could be 165.2 cm, 165.23 cm, or any value within a continuous range, making it a continuous variable. Graphically, continuous distributions are represented as smooth curves, such as the normal distribution (bell curve).
#
#
# Question.4 What are probability distribution functions (PDF)?
# ---  A Probability Distribution Function (PDF) describes how probabilities are assigned to different values of a random variable in a given probability distribution. It provides a mathematical way to model uncertainty and randomness.
#
#
# Question.5 How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# --- The Cumulative Distribution Function (CDF) and Probability Distribution Function (PDF) serve different purposes in probability theory.
#
# A Probability Distribution Function (PDF) describes how probabilities are distributed over the possible values of a random variable. For discrete random variables, this is given by the Probability Mass Function (PMF), while for continuous random variables, it is described by the Probability Density Function (PDF). The PDF (or PMF) provides the likelihood of a specific value occurring.In contrast, the Cumulative Distribution Function (CDF) gives the probability that the random variable is less than or equal to a given value.
#
#
# Question.6 What is a discrete uniform distribution?
# --- A discrete uniform distribution is a probability distribution where a finite number of outcomes are equally likely to occur. This means that each value in the set has the same probability of being chosen.
#
#
# Question.7 What are the key properties of a Bernoulli distribution?
# --- The Bernoulli distribution is a discrete probability distribution that models a single trial of an experiment with only two possible outcomes: success (1) or failure (0). It is the simplest type of probability distribution.
#
#
# Question.8 What is the binomial distribution, and how is it used in probability?
# ---  The binomial distribution is a discrete probability distribution that describes the number of successes in a fixed number of independent Bernoulli trials, where each trial has only two possible outcomes: success (1) or failure (0).
#
# Definition
# A random variable
# 𝑋
# X follows a binomial distribution if:
#
# There are
# 𝑛
# n independent trials.
#
# Each trial has only two outcomes (success or failure).
#
# The probability of success in each trial is
# 𝑝
# p, and the probability of failure is
# 1
# −
# 𝑝
# 1−p.
#
# The trials are independent, meaning the outcome of one trial does not affect another.
#
#
# Question.9 What is the Poisson distribution and where is it applied?
# --- The Poisson distribution is a discrete probability distribution that describes the probability of a given number of events occurring in a fixed interval of time or space, assuming the events happen independently and at a constant average rate.
#
# Definition
# A random variable
# 𝑋
# X follows a Poisson distribution if it represents the number of occurrences of an event in a given interval and satisfies the following conditions:
#
# Events occur independently (one event does not affect another).
#
# The probability of more than one event occurring in a very small interval is negligible.
#
# The average rate
# 𝜆
# λ (expected number of occurrences per interval) is constant.
#
#
# Question.10 What is a continuous uniform distribution?
# --- The continuous uniform distribution is a probability distribution where all values in a given range are equally likely to occur. It is also called the rectangular distribution because its probability density function (PDF) is constant, forming a flat horizontal line when graphed.
# Applications of Continuous Uniform Distribution
# ✅ Random Number Generation: Used in simulations and Monte Carlo methods.
# ✅ Quality Control: Modeling uniform errors in a process.
# ✅ Gaming & Lottery Systems: Assigning equal probabilities to different outcomes.
# ✅ Physics & Engineering: Modeling events with equal probability, like waiting times in some systems.
#
#
# Question.11 What are the characteristics of a normal distribution?
# --- The normal distribution is one of the most important and widely used probability distributions in statistics. It is often referred to as the Gaussian distribution and is characterized by its bell-shaped curve, which is symmetric around the mean. The normal distribution is commonly used to model a wide variety of natural phenomena, such as heights, weights, test scores, and measurement errors
#
#
# Question.12 What is the standard normal distribution, and why is it important?
# --- The standard normal distribution is a special case of the normal distribution where the mean is 0 and the standard deviation is 1. It is commonly denoted as
# 𝑍
# ∼
# 𝑁
# (
# 0
# ,
# 1
# )
# Z∼N(0,1), and its probability density function (PDF) is the same as that of a normal distribution, except that it is scaled for a mean of 0 and a standard deviation of 1.
#
# Characteristics of the Standard Normal Distribution
# Mean (μ):
# The mean of a standard normal distribution is 0. This means that the peak of the bell curve is centered at 0 on the horizontal axis.
#
# Standard Deviation (σ):
# The standard deviation is 1 in the standard normal distribution, meaning the spread or width of the curve is controlled by this value. This standard deviation determines how "tight" or "wide" the bell-shaped curve is.
#
# Symmetry:
# The standard normal distribution is symmetric around the mean (0). This means the left and right halves of the curve are mirror images of each other.
#
# Why is the Standard Normal Distribution Important?
# Simplification of Calculations:
#
# The standard normal distribution simplifies the calculation of probabilities and percentiles for any normal distribution. Instead of directly working with any normal distribution with arbitrary mean and standard deviation, you can transform any normal distribution to the standard normal form using z-scores.
#
# The z-table (or standard normal table) is used to find the probability of a value occurring in a standard normal distribution, making it easy to calculate probabilities for any normal distribution once it’s transformed into standard normal form.
#
# Central Limit Theorem (CLT):
#
# The central limit theorem states that the sum (or average) of a large number of independent random variables, regardless of the original distribution, will tend to follow a normal distribution as the number of variables increases.
#
# By transforming data to the standard normal distribution, we can easily work with the properties of normal distributions in practical situations, like hypothesis testing or constructing confidence intervals.
#
# Statistical Significance and Hypothesis Testing:
#
# In hypothesis testing, the standard normal distribution plays a key role in calculating p-values and determining statistical significance. For example, in Z-tests, the test statistic follows a standard normal distribution, and we can use z-scores to compare observed data against expected data.
#
# Confidence intervals and other statistical analyses often involve comparing observed data to the standard normal distribution to assess how extreme the results are.
#
# Universal Applicability:
#
# Since many natural phenomena (such as human heights, test scores, measurement errors, etc.) follow normal distributions, the standard normal distribution serves as a universal reference for statistical analysis across different fields, including psychology, economics, engineering, and biology.
#
#
# Question.13 What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# --- The Central Limit Theorem (CLT) is one of the most important concepts in statistics, and it states that the sampling distribution of the sample mean (or sum) will approach a normal distribution as the sample size increases, regardless of the shape of the population distribution, provided the samples are independent and identically distributed (i.i.d.).
#
#
# Question.14 How does the Central Limit Theorem relate to the normal distribution?
# --- The Central Limit Theorem (CLT) is directly related to the normal distribution because it explains why and how the sampling distribution of the sample mean tends to follow a normal distribution, even if the population from which the sample is drawn is not normally distributed. The CLT is a fundamental concept in statistics that bridges the gap between non-normal populations and normal distribution-based statistical methods.
# How the Central Limit Theorem Relates to the Normal Distribution:
# Transforming Non-Normal Distributions to Normal:
#
# The CLT tells us that regardless of the population's distribution (whether it’s skewed, uniform, exponential, etc.), the distribution of the sample mean will approach a normal distribution as the sample size
# 𝑛
# n becomes large enough.
#
# This is crucial because many statistical methods (e.g., hypothesis testing, confidence intervals) rely on the assumption that data follows a normal distribution. The CLT justifies the use of these methods even if the underlying population is not normal, as long as the sample size is sufficiently large.
#
# Sampling Distribution of the Sample Mean:
#
# The sampling distribution of the sample mean is the distribution of means from all possible random samples of a specific size from a population. According to the CLT, as the sample size increases, this sampling distribution will approximate a normal distribution, with:
#
# Mean
# 𝜇
# μ (the same as the population mean),
#
# Standard deviation
# 𝜎
# 𝑛
# n
# ​
#
# σ
# ​
#  , where
# 𝜎
# σ is the population standard deviation, and
# 𝑛
# n is the sample size.
#
# The larger the sample size, the closer the sampling distribution will resemble a normal distribution, even if the population distribution is skewed or has other non-normal characteristics.
# Why the Normal Distribution Appears:
#
# The reason the sampling distribution of the sample mean tends to a normal distribution as the sample size increases is due to the law of large numbers and the central limit phenomenon. As more and more independent data points are averaged, the random fluctuations (or "noise") of the individual values cancel each other out, and the distribution of the sample mean becomes symmetric and bell-shaped (i.e., normal).
#
# This happens because the sum of many independent random variables, each with its own distribution, will result in a distribution that approaches normality, as shown by the CLT.
#
# Approximation to Normality:
#
# When the sample size is large (usually
# 𝑛
# ≥
# 30
# n≥30 is considered sufficiently large), the sampling distribution of the sample mean can be approximated by a normal distribution. This is true even if the original population is not normally distributed.
#
# For smaller sample sizes, if the population is not normal, the sampling distribution may not be well-approximated by a normal distribution, and the CLT may require a larger sample size to hold.
#
# Practical Example of the CLT and Normal Distribution:
#
# Suppose you are studying the heights of individuals in a large city. The population distribution might be skewed or have outliers, making it non-normal.
#
# However, if you repeatedly take samples of size 50 and calculate the mean height for each sample, the distribution of those sample means will start to resemble a normal distribution as the number of samples increases, due to the CLT.
#
# Question.15 How do you calculate a Z-score, and what does it represent?
# --- In hypothesis testing, Z-statistics (or Z-scores) play a critical role, especially when the population standard deviation is known or when the sample size is large enough to approximate the sampling distribution of the sample mean to be normal, according to the Central Limit Theorem (CLT).
#
# Applications of Z-statistics in Hypothesis Testing:
# Hypothesis Testing for Population Mean (when σ is known): When the population standard deviation (
# 𝜎
# σ) is known and we want to test a hypothesis about the population mean (
# 𝜇
# μ), the Z-statistic is used to determine how far the sample mean is from the population mean, expressed in terms of standard deviations.
#
#
# Question.16 What are point estimates and interval estimates in statistics?
# --- In statistics, point estimates and interval estimates are two key types of estimates used to infer unknown population parameters (such as the population mean, proportion, or variance) based on sample data.
#
# Point Estimate:
# A point estimate is a single value (or point) used to estimate an unknown population parameter. It is calculated from a sample and provides the best guess or approximation of the parameter, but it does not account for uncertainty or variability. Essentially, a point estimate gives one specific value, but it doesn't provide any range of possible values for the parameter.
#
#
# Question.17 What are point estimates and interval estimates in statistics?
# --- In statistics, point estimates and interval estimates are two key types of estimates used to infer unknown population parameters (such as the population mean, proportion, or variance) based on sample data.
#
# Point Estimate:
# A point estimate is a single value (or point) used to estimate an unknown population parameter. It is calculated from a sample and provides the best guess or approximation of the parameter, but it does not account for uncertainty or variability. Essentially, a point estimate gives one specific value, but it doesn't provide any range of possible values for the parameter.
# Interval Estimate:
# An interval estimate provides a range of values within which the population parameter is likely to fall, along with a measure of the confidence or probability that the parameter lies within that range. This type of estimate accounts for the inherent uncertainty in sampling by providing a confidence interval (CI) that expresses the potential variation in the estimate due to random sampling.
#
#
# Question.18 What is the significance of confidence intervals in statistical analysis?
# --- In statistical analysis, confidence intervals (CIs) play a crucial role in providing a range of values within which the true population parameter is likely to fall. They are a fundamental concept in inferential statistics, as they not only provide an estimate of the population parameter (like a mean or proportion) but also indicate the level of uncertainty or variability associated with that estimate. The significance of confidence intervals lies in their ability to:
#
# 1. Quantify Uncertainty:
# Confidence intervals give us a way to quantify uncertainty about a sample estimate. For instance, when we estimate the population mean from a sample mean, we cannot be 100% certain that the sample mean is exactly the same as the true population mean. The confidence interval provides a range of values that likely contains the true population parameter. This helps us understand the precision of our estimate.
#
# Example:
# If you calculate a 95% confidence interval for the average height of a group of people as [160 cm, 170 cm], you can say that you are 95% confident that the true average height of the population lies within this range.
#
# 2. Provide a Measure of Reliability:
# The confidence level associated with the interval (such as 90%, 95%, or 99%) tells us how reliable the interval is. For a 95% confidence interval, we can say that if we were to repeatedly take samples from the population and calculate the confidence interval each time, 95% of those intervals would contain the true population parameter. This gives a sense of how consistently our estimate would perform across repeated sampling.
#
# Example:
# If you calculate a 95% CI for the average income in a city and it’s [₹40,000, ₹45,000], it means that, based on your sample, you are 95% confident that the true average income lies in this range.
#
# 3. Allow for Decision Making:
# Confidence intervals are widely used in hypothesis testing and help in decision-making. They provide a range of plausible values for the population parameter. If a hypothesized value falls outside the confidence interval, it may indicate that the null hypothesis can be rejected. Similarly, if a confidence interval for a difference between two groups does not contain zero, this suggests that there is a statistically significant difference between the groups.
#
# Example:
# If you are testing the effectiveness of a new drug and the 95% confidence interval for the difference in recovery rates between the drug and a placebo is [5%, 15%], it suggests that the drug is likely to have a positive effect, as zero is not included in the interval.
#
# 4. Enable Comparisons:
# Confidence intervals are useful for comparing two or more estimates. If the confidence intervals of two estimates do not overlap, this provides evidence that the two estimates are significantly different from each other. On the other hand, if the intervals overlap significantly, it suggests that the difference between the estimates may not be statistically significant.
#
# Example:
# If the 95% confidence interval for the average salary of workers in two different companies is [₹50,000, ₹55,000] for Company A and [₹52,000, ₹58,000] for Company B, the intervals overlap, suggesting that there may not be a significant difference between the two companies’ average salaries.
#
# 5. Help in Estimating Population Parameters:
# Confidence intervals are used to estimate population parameters based on sample data. They provide a more nuanced understanding than point estimates by incorporating variability into the estimate. This is particularly important because we rarely know the true values of population parameters; instead, we rely on sample data to make informed estimates.
#
# Example:
# Suppose you survey 100 people in a city to estimate the proportion of people who support a certain policy. The point estimate might suggest that 60% of the population supports it. But the 95% confidence interval might be [55%, 65%], meaning the true proportion of supporters in the population is likely to be within that range.
#
# 6. Account for Sample Size:
# The width of the confidence interval is influenced by the sample size. Larger sample sizes tend to produce narrower confidence intervals, providing more precise estimates of the population parameter. Conversely, smaller sample sizes result in wider intervals, indicating greater uncertainty about the population parameter.
#
# Example:
# A survey with 1,000 respondents will yield a more precise estimate (narrower confidence interval) of public opinion than a survey with only 50 respondents.
#
# 7. Help in Statistical Inference:
# Confidence intervals are central to statistical inference, providing a range of plausible values for population parameters. This range allows researchers to make conclusions based on sample data, without making absolute claims. Confidence intervals thus offer a more flexible way of interpreting data, as they reflect uncertainty and variability, while point estimates only provide a single value.
#
# Example:
# When testing whether the mean weight of apples in an orchard is equal to a certain value, a 95% confidence interval might show a range of values, helping the researcher decide whether the observed sample mean is consistent with the hypothesized population mean.
#
# Key Benefits of Confidence Intervals:
# Provide a range of plausible values for the population parameter.
#
# Quantify the uncertainty around an estimate, offering insight into its precision.
#
# Help in hypothesis testing, decision-making, and understanding the significance of results.
#
# Allow comparisons between different estimates (such as differences between groups).
#
# Incorporate sample size effects by adjusting the width of the interval accordingly.
#
# Improve interpretation of statistical results by offering a more comprehensive understanding than point estimates alone.
#
# Limitations of Confidence Intervals:
# Not a guarantee: A confidence interval does not guarantee that the true population parameter lies within the interval. For example, a 95% confidence interval means that there’s a 5% chance the true parameter is outside the interval, but this does not imply that the interval is wrong.
#
# Sensitive to sample size: Smaller sample sizes lead to wider intervals, which may limit the precision of the estimate.
#
#
# Question.19 What is the relationship between a Z-score and a confidence interval?
# ---The Z-score and confidence intervals are closely related concepts in statistics, particularly when dealing with normal distributions. Both are used to describe how far a sample statistic (such as the sample mean) is from the population parameter, and they work together in constructing confidence intervals.
#
#
# Question.20 How are Z-scores used to compare different distributions?
# --- Z-scores are a powerful tool in statistics that allow for the comparison of values from different distributions, even if the distributions have different means and standard deviations. By standardizing data using Z-scores, we transform the values into a common scale (the standard normal distribution), which allows for meaningful comparisons across different datasets or distributions.
#
# Summary of Z-Scores and Comparison of Distributions:
# Z-scores standardize data from different distributions, allowing for meaningful comparisons.
#
# They provide a way to compare values relative to their respective means and standard deviations, regardless of the original scales.
#
# Z-scores help you understand how extreme a value is within its distribution and compare relative positions of values from different distributions.
#
# They are especially useful in detecting outliers, making decisions in hypothesis testing, and comparing values across distributions with different units or scales.
#
#
# Question.21 What are the assumptions for applying the Central Limit Theorem?
# --- The Central Limit Theorem (CLT) is a fundamental concept in statistics that states that, for a sufficiently large sample size, the sampling distribution of the sample mean (or sum) will be approximately normally distributed, regardless of the shape of the original population distribution. However, for the CLT to hold effectively.
# Summary of Assumptions:
# Independence of observations.
#
# Random sampling.
#
# Sample size is large enough (usually
# 𝑛
# ≥
# 30
# n≥30).
#
# Population distribution should be normal for small samples, but the CLT still applies for larger samples even if the population is not normal.
#
# Finite variance in the population.
#
# Outliers should not be extreme (especially for smaller samples).
#
#
# Question.22 What is the concept of expected value in a probability distribution?
# --- The expected value in a probability distribution is a key concept in probability theory and statistics, representing the average or mean of a random variable. It provides a measure of the central tendency of the distribution, essentially describing the long-term average of the outcomes you would expect if an experiment is repeated many times.
#
# 1. Definition and Concept:
# The expected value (also called the mean or mathematical expectation) of a random variable is the weighted average of all possible values the random variable can take, where each value is weighted by its probability.
#
# It is a way to summarize the distribution of a random variable by giving a single number that describes where the values of the random variable tend to cluster or the "center" of the distribution.
#
#
# Question.23 How does a probability distribution relate to the expected outcome of a random variable?
# ---The expected value (also known as the mean or mathematical expectation) of a probability distribution is a fundamental concept in probability theory and statistics. It represents the average or center of a probability distribution, providing a measure of the "central tendency" of the random variable. Essentially, the expected value gives you a long-run average or a weighted average of all possible outcomes of a random variable, based on their probabilities.
# The expected value is the average or center of a probability distribution, representing the long-term average of a random variable.
#
# It is calculated as the weighted sum of all possible outcomes (for discrete variables) or the integral of the product of the outcome and the probability density (for continuous variables).
#
# The expected value is widely used in decision-making, risk assessment, gambling, finance, and many other fields, though it does not provide information about the spread or variability of the outcomes.

# %%
#Question.1 Write a Python program to generate a random variable and display its value.

import random


random_variable = random.randint(1, 10)


print("The randomly generated variable is:", random_variable)
# Out:
# The randomly generated variable is: 10

# %%
#Question.2 Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the discrete uniform distribution
low = 1   # Lowest possible value
high = 6  # Highest possible value (inclusive)

# Generate a sample of random variables from the discrete uniform distribution
sample_size = 1000
random_samples = np.random.randint(low, high + 1, size=sample_size)

# Calculate the probability mass function (PMF)
values, counts = np.unique(random_samples, return_counts=True)
pmf = counts / sample_size  # PMF is the relative frequency of each value

# Plotting the PMF
plt.figure(figsize=(8, 6))
plt.stem(values, pmf, basefmt=" ", linefmt="b-", markerfmt="bo", label="PMF")
plt.title("Probability Mass Function of Discrete Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.xticks(values)
plt.ylim(0, 1.1 * max(pmf))  # Adjust the y-axis to show PMF clearly
plt.grid(True)
plt.legend()
plt.show()

# %%
#Question.3 Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution

def bernoulli_pdf(x, p):
    """
    Calculate the probability distribution function (PDF) of a Bernoulli distribution.

    Parameters:
    x (int): The outcome of the random variable (0 or 1).
    p (float): The probability of success (0 <= p <= 1).

    Returns:
    float: The probability of the outcome x.
    """
    if x == 1:
        return p
    elif x == 0:
        return 1 - p
    else:
        raise ValueError("x must be either 0 or 1")

# Example usage:
p = 0.7  # Probability of success
x = 1    # Outcome: success (1)

# Calculate PDF for the outcome x
pdf = bernoulli_pdf(x, p)

# %%
#Question.4 Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.




import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10   # Number of trials
p = 0.5  # Probability of success

# Simulate a binomial distribution by generating random samples
sample_size = 1000  # Number of random samples to generate
binomial_samples = np.random.binomial(n, p, sample_size)

# Plotting the histogram
plt.figure(figsize=(8, 6))
plt.hist(binomial_samples, bins=np.arange(n+2) - 0.5, edgecolor='black', density=True)
plt.title(f"Histogram of Binomial Distribution (n={n}, p={p})")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.xticks(range(n+1))
plt.grid(True)
plt.show()

# %%
#Question.5 Create a Poisson distribution and visualize it using Python.
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Poisson distribution
lambda_ = 3  # Average number of events (mean rate)
sample_size = 1000  # Number of random samples to generate

# Generate random samples from a Poisson distribution
poisson_samples = np.random.poisson(lambda_, sample_size)

# Plotting the Poisson distribution
plt.figure(figsize=(8, 6))
plt.hist(poisson_samples, bins=range(0, max(poisson_samples)+1), edgecolor='black', density=True)
plt.title(f"Poisson Distribution (λ={lambda_})")
plt.xlabel("Number of Events")
plt.ylabel("Probability")
plt.xticks(range(0, max(poisson_samples)+1))
plt.grid(True)
plt.show()

# %%
#Question.6 Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

import numpy as np
import matplotlib.pyplot as plt

# Parameters for the discrete uniform distribution
low = 1   # Lowest possible value
high = 6  # Highest possible value (inclusive)

# Generate a sample of random variables from the discrete uniform distribution
sample_size = 1000  # Number of random samples to generate
random_samples = np.random.randint(low, high + 1, size=sample_size)

# Calculate the probability mass function (PMF)
values, counts = np.unique(random_samples, return_counts=True)
pmf = counts / sample_size  # PMF is the relative frequency of each value

# Calculate the cumulative distribution function (CDF)
cdf = np.cumsum(pmf)  # CDF is the cumulative sum of the PMF

# Plotting the CDF
plt.figure(figsize=(8, 6))
plt.step(values, cdf, where='post', label="CDF", color='b', linestyle='-', marker='o')
plt.title(f"Cumulative Distribution Function of Discrete Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.xticks(values)
plt.ylim(0, 1.1)  # The CDF should never exceed 1
plt.grid(True)
plt.legend()
plt.show()

# %%
#Question.7 Generate a continuous uniform distribution using NumPy and visualize it
import numpy as np
import matplotlib.pyplot as plt

# Generate random samples from a uniform distribution
samples = np.random.uniform(low=0, high=1, size=1000)

# Visualize the distribution
plt.hist(samples, bins=30, edgecolor='black', alpha=0.7)
plt.title('Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
#Question 8. Simulate Data from a Normal Distribution and Plot Its Histogram

# Generate random samples from a normal distribution
mean = 0
std_dev = 1
samples = np.random.normal(loc=mean, scale=std_dev, size=1000)

# Plot the histogram
plt.hist(samples, bins=30, edgecolor='black', alpha=0.7)
plt.title('Normal Distribution Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
#Question  9. Write a Python Function to Calculate Z-scores from a Dataset and Plot Them

def calculate_z_scores(data):
    mean = np.mean(data)
    std_dev = np.std(data)
    z_scores = (data - mean) / std_dev
    return z_scores

# Generate some data
data = np.random.normal(loc=0, scale=1, size=1000)
z_scores = calculate_z_scores(data)

# Plot the Z-scores
plt.hist(z_scores, bins=30, edgecolor='black', alpha=0.7)
plt.title('Z-scores')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.show()

# %%
#Question 10. Implement the Central Limit Theorem (CLT) for a Non-Normal Distribution


# Sample from an exponential distribution (non-normal)
samples = np.random.exponential(scale=2, size=1000)

# Perform the CLT by taking random samples from the distribution
sample_means = []
for _ in range(1000):
    sample = np.random.choice(samples, size=30)
    sample_means.append(np.mean(sample))

# Plot the sample means
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7)
plt.title('Central Limit Theorem: Sample Means Distribution')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.show()

# %%
#Question 11. Simulate Multiple Samples from a Normal Distribution and Verify the Central Limit Theorem

# Generate multiple samples from a normal distribution
samples = np.random.normal(loc=0, scale=1, size=(1000, 30))

# Calculate the means of each sample
sample_means = np.mean(samples, axis=1)

# Plot the sample means to verify the CLT
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7)
plt.title('CLT: Sample Means from Normal Distribution')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.show()

# %%
#Question 12. Write a Python Function to Calculate and Plot the Standard Normal Distribution

import scipy.stats as stats

def plot_standard_normal_distribution():
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x, loc=0, scale=1)

    plt.plot(x, y, label="Standard Normal Distribution")
    plt.title('Standard Normal Distribution (Mean=0, Std=1)')
    plt.xlabel('Value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.show()

# Plot the standard normal distribution
plot_standard_normal_distribution()

# %%
#Question   13. Generate Random Variables and Calculate Their Corresponding Probabilities Using the Binomial Distribution

# Generate binomially distributed random variables
n = 10  # number of trials
p = 0.5  # probability of success
size = 1000  # number of samples
binom_samples = np.random.binomial(n, p, size)

# Plot histogram of binomial distribution
plt.hist(binom_samples, bins=20, edgecolor='black', alpha=0.7)
plt.title('Binomial Distribution')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.show()

# Calculate probabilities (example for x = 5 successes)
prob = stats.binom.pmf(5, n, p)
print(f'P(X=5): {prob}')
# Out:
# P(X=5): 0.24609375000000003

# %%
#Question 14. Write a Python Program to Calculate the Z-score for a Given Data Point and Compare It to a Standard Normal Distribution

def calculate_z_score(data_point, mean, std_dev):
    return (data_point - mean) / std_dev

# Example data
data_point = 1.5
mean = 0
std_dev = 1

z_score = calculate_z_score(data_point, mean, std_dev)

# Compare the Z-score to a standard normal distribution
probability = stats.norm.cdf(z_score)
print(f'Z-score: {z_score}')
print(f'Probability from standard normal distribution: {probability}')
# Out:
# Z-score: 1.5
# Probability from standard normal distribution: 0.9331927987311419

# %%
#Question 15. Implement Hypothesis Testing Using Z-statistics for a Sample Dataset

def z_test(sample, population_mean, population_std_dev):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    z_stat = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))
    return z_stat

# Example sample and population parameters
sample = np.random.normal(loc=100, scale=15, size=30)
population_mean = 105
population_std_dev = 15

z_stat = z_test(sample, population_mean, population_std_dev)
print(f'Z-statistic: {z_stat}')
# Out:
# Z-statistic: -4.721756967414046

# %%
#Question 16. Create a Confidence Interval for a Dataset Using Python and Interpret the Result

import scipy.stats as stats

def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    std_dev = np.std(data)
    n = len(data)
    se = std_dev / np.sqrt(n)

    # Calculate the confidence interval
    ci = stats.t.interval(confidence, n-1, loc=mean, scale=se)
    return ci

# Generate data
data = np.random.normal(loc=50, scale=10, size=100)
ci = confidence_interval(data)

print(f'Confidence Interval: {ci}')
# Out:
# Confidence Interval: (np.float64(49.284189192080724), np.float64(53.12343769744984))

# %%
#Question 17. Generate Data from a Normal Distribution, Then Calculate and Interpret the Confidence Interval for Its Mean

data = np.random.normal(loc=100, scale=15, size=50)

# Calculate 95% confidence interval for the mean
ci = confidence_interval(data, confidence=0.95)
print(f'Confidence Interval for Mean: {ci}')
# Out:
# Confidence Interval for Mean: (np.float64(90.22166310397355), np.float64(98.08173668155649))

# %%
#Question 18. Write a Python Script to Calculate and Visualize the Probability Density Function (PDF) of a Normal Distribution

def plot_pdf_normal_distribution():
    x = np.linspace(-5, 5, 1000)
    y = stats.norm.pdf(x, loc=0, scale=1)

    plt.plot(x, y)
    plt.title('Normal Distribution PDF (Mean=0, Std=1)')
    plt.xlabel('Value')
    plt.ylabel('Probability Density')
    plt.show()

plot_pdf_normal_distribution()

# %%
#Question 19. Use Python to Calculate and Interpret the Cumulative Distribution Function (CDF) of a Poisson Distribution

# Calculate CDF for Poisson distribution
lambda_ = 3  # rate parameter
x = np.arange(0, 10)
cdf_values = stats.poisson.cdf(x, mu=lambda_)

# Plot CDF
plt.step(x, cdf_values, where='post')
plt.title('Poisson Distribution CDF (lambda=3)')
plt.xlabel('Number of Events')
plt.ylabel('Cumulative Probability')
plt.show()

# %%
#Question  20. Simulate a Random Variable Using a Continuous Uniform Distribution and Calculate Its Expected Value

# Simulate random variable
uniform_samples = np.random.uniform(low=0, high=1, size=1000)

# Calculate the expected value (mean) for the uniform distribution
expected_value = np.mean(uniform_samples)
print(f'Expected Value: {expected_value}')
# Out:
# Expected Value: 0.5021166725706959

# %%
#Question  21. Write a Python Program to Compare the Standard Deviations of Two Datasets and Visualize the Difference

data1 = np.random.normal(loc=50, scale=10, size=100)
data2 = np.random.normal(loc=50, scale=5, size=100)

# Calculate standard deviations
std_dev1 = np.std(data1)
std_dev2 = np.std(data2)

# Visualize the difference
plt.hist(data1, bins=30, alpha=0.7, label=f'Data1 (std={std_dev1:.2f})')
plt.hist(data2, bins=30, alpha=0.7, label=f'Data2 (std={std_dev2:.2f})')
plt.legend()
plt.title('Comparison of Standard Deviations')
plt.show()

# %%
#Question 22. Calculate the Range and Interquartile Range (IQR) of a Dataset Generated from a Normal Distribution

data = np.random.normal(loc=50, scale=10, size=100)

# Calculate range and IQR
range_val = np.ptp(data)
iqr_val = np.percentile(data, 75) - np.percentile(data, 25)

print(f'Range: {range_val}')
print(f'IQR: {iqr_val}')
# Out:
# Range: 46.58022098332541
# IQR: 11.19669461516672

# %%
#Question  23. Implement Z-score Normalization on a Dataset and Visualize Its Transformation

def z_score_normalization(data):
    mean = np.mean(data)
    std_dev = np.std(data)
    return (data - mean) / std_dev

# Generate data
data = np.random.normal(loc=50, scale=10, size=100)

# Normalize data
normalized_data = z_score_normalization(data)

# Plot the original vs normalized data
plt.hist(data, bins=30, alpha=0.7, label='Original Data')
plt.hist(normalized_data, bins=30, alpha=0.7, label='Normalized Data')
plt.legend()
plt.title('Z-score Normalization')
plt.show()

# %%
#Question  24. Write a Python Function to Calculate the Skewness and Kurtosis of a Dataset Generated from a Normal Distribution

from scipy.stats import skew, kurtosis

def calculate_skew_kurtosis(data):
    skewness = skew(data)
    kurt = kurtosis(data)
    return skewness, kurt

data = np.random.normal(loc=0, scale=1, size=1000)

skewness, kurt = calculate_skew_kurtosis(data)
print(f'Skewness: {skewness}')
print(f'Kurtosis: {kurt}')
# Out:
# Skewness: -0.0637179866187057
# Kurtosis: -0.06589992289982405
